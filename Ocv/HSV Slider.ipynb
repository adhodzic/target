# %%
import cv2
import sys
import numpy as np

def nothing(x):
    pass

useCamera=False

# Check if filename is passed
if (len(sys.argv) <= 1) :
    print ("'Usage: python hsvThresholder.py <ImageFilePath>' to ignore camera and use a local image.")
    useCamera = True

# Create a window
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('HMin','image',0,179,nothing) # Hue is from 0-179 for Opencv
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

# Set default value for MAX HSV trackbars.
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize to check if HSV min/max value changes
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

# Output Image to display
if useCamera:
    cap = cv2.VideoCapture(0)
    # Wait longer to prevent freeze for videos.
    waitTime = 330
else:
    img = cv2.imread('./images/targets/img7.jpg')
    w = img.shape[1]
    h = img.shape[0]

    ratio = h/w
    dim = (500, int(500*ratio))
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    output = img
    waitTime = 33

while(1):

    if useCamera:
        # Capture frame-by-frame
        ret, img = cap.read()
        img = cv2.resize(img,(700,480))
        output = img
    
    # get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    # Set minimum and max HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Create HSV Image and threshold into a range.
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(img,img, mask= mask)

    # Print if there is a change in HSV value
    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display output image
    cv2.imshow('image',output)

    # Wait longer to prevent freeze for videos.
    if cv2.waitKey(waitTime) & 0xFF == ord('q'):
        break

# Release resources
if useCamera:
    cap.release()
cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 58 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 65 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 68 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 65 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 2), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 6), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 7), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 13), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 16), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 19), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 25), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 30), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 39), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 55), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 62), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 80), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 85), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 87), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 89), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 93), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 98), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 106), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 109), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 111), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 112), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 113), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 114), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 116), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 112), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 109), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 106), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 105), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 104), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 96), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 101), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 104), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 106), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 107), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 109), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 110), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 112), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 114), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 117), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 119), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 123), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 125), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 126), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 128), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 134), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 136), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 138), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 141), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 146), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 153), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 157), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 158), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 159), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 160), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 158), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 155), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 152), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 150), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 145), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 141), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 136), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 130), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 125), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 123), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 120), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 116), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 113), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 109), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 104), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 94), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 99), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 100), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 101), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 102), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 104), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 105), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 106), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 107), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 109), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 107), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 82 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 85 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 86 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 89 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 91 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 92 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 96 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 98 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 99 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 109 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 114 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 117 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 120 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 124 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 127 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 117 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 109 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 105 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 97 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 58 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 77 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 77 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 248, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 239, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 226, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 215, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 206, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 201, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 190, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 180, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 167, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 151, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 138, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 121, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 109, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 95, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 83, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 69, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 59, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 53, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 49, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 47, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 44, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 42, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 41, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 39, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 38, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 55, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 89, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 114, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 141, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 170, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 191, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 229, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 247, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 226)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 207)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 190)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 164)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 135)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 100)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 81)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 68)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 58)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 51)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 45)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 44)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 46)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 69)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 85)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 94)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 109)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 122)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 145)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 165)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 183)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 201)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 209)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 220)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 228)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 231)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 236)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 242)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 248)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 249, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 225, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 218, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 217, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 216, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 207, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 195, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 185, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 173, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 162, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 151, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 142, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 137, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 134, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 130, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 121, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 114, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 106, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 100, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 98, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 94, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 91, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 88, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 86, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 85, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 84, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 83, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 100, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 117, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 143, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 168, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 182, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 200, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 219, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 228, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 236, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 246, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 254, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 108), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = -1 , sMin = -1, vMin = -1), (hMax = -1 , sMax = -1, vMax = -1)
